# %% [markdown]
# ### Giving Credits to [Computer Networking Full Course](https://www.youtube.com/watch?v=IPvYjXCsTg8)

# %% [markdown]
# Client-Server Architecture
#
# TCP: Transmission Control Protocol (delivery of a stream of data between applications running on hosts communicating over an IP network.)
#
# UDP: User Datagram Protocol (a core communication protocol used for establishing low-latency and loss-tolerating connections between applications on the internet.efficient alternative to TCP)
#     Unlike "handshake": it operates on a "fire-and-forget" basis, where data packets, known as datagrams, are sent to the destination without any guarantee of delivery, order, or error correction
#
# HTTP: Hypertext Transfer Protocol, stands as the foundational protocol for data communication on the World Wide Web
#
# Packets: a packet is a small, manageable block of data that is transmitted over a network
#
# IP address(X.X.X.X) each x is ranged from 0 to 255
#     curl ifconfig.me -s gives you the IP address of your internet
#
# ISP: Internet Service Provider (a company that provides individuals and organizations with access to the internet and other related services.)
#
# DHCP
#
# NAT: how different applications using different port numbers
#     total port number is: 2^16, 16 bits
#     0-1023: reserved ports
#     1024-49152: applications
#     remainings: you can use
#
# 1 mbps = 1*10^6 bits/second
# 1 gbps = 1*10^9 bits/second
# 1 kbps = 1000 bits/s

# %% [markdown]
# LAN: local area network(small house/office), wifi
# MAN: across a city
# WAN: Across countries(optical fiber cables)
#
# sonet: Synchronous Optical Network, is a standardized protocol for transmitting a large volume of digital data over optical fibe
# frame relay: Frame Relay was a high-performance Wide Area Network (WAN) protocol that played a crucial role in connecting geographically separated Local Area Networks (LANs) during the 1990s and early 2000s. It operated at the Data Link layer (Layer 2) of the OSI model and utilized a form of packet switching.

# %% [markdown]
# Topologies:
# Bus: only one computer can send data at once
# Ring: a cycle, one break makes trouble
# Star: one centralized device, if it fails, error
# Tree: (bus + star)
# Mesh:  one computer is connected to every single computer, expensive, to many wires used, scaling issues

# %% [markdown]
# Structure of two networks:
#
# OSI: open system interconnection model
# 7 layers:
# Application: software
# Presentation: convert the data from application layer to machine language
# Session: setting up connections
# Transportation: data segment, port number, a sequence number(reassemble the segments in correct order)
# Network:(router) work for the transmission of three data segments from one computer to another in different network. logical addressing
#
# Data Link: logical addressing, physical addressing (MAC address)
# Physical: physical router (wires )
#
# TCP/IP model
# Application:
#     1. users interactive with
#     2. apps, web browsers
#     3. where: devices
#     4. protocals
#     5. client-server Architecture
#     6. P2P: peer to peer (be able to scaling fast)
# command: ping google.com
#
# Transportation:
#
# (Brouter: combines features of bridge and router, works at either Network or Data link)
# Network:(router: like switch, routes data packets based on their IP addresses, gateway: connects two network together upon different networking models)
# Data Link:(bridges: 2 port device, two types: Transparent Bridges, Source Routing Bridges, Switch: multiport bridge)
# Physical: (repeater: works on physical layer, 2 port device. hub: multiport repeater)

# %% [markdown]
# Protocols:
# web protocols:
# TCP/IP:
#     HTTP(stateless, don't store info for clients)(works at application layer): use TCP for transportation layer
#     DHCP(works at application layer): Dynamic Host Configuration Protocol, assigns IP addresses and other network configuration information to devices on a network.
#     FTP: transfer computer files between a client and a server on a network.
#     SMTP
#     POP3 &IMAC
#     SSH
#     VNC
# Telnet(application layer, almost replaced by ssh): port 23, provide a command-line interface to communicate with a remote device or server.
# UDP(Transport Layer): stateless communication, Connectionless(doesn't establish a formal connection (like a "handshake") before sending data. It just sends the message, often called a datagram.), Unreliable(doesn't guarantee that the data packets will arrive at their destination, nor does it ensure they will arrive in the correct order)
#
# Sockets: It combines an IP address and a port number to create a unique communication channel. Active Connection: Client Socket + Server Socket
# ports: Ephemeral ports: A port is a number used to identify a specific process or service on a device
