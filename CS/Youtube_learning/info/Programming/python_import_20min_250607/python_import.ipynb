# %% [markdown]
# ### Giving Credits to [What does '__init__.py' do in Python?]( https://www.youtube.com/watch?v=VEbuZox5qC4)
#
# directly import the packages without __init__.py
# ![pic1](images/pic1.png)
# using __init__.py(run main.py not run the __init__.py)
# ![pic2](images/pic2.png)
# ![pic3](images/pic3.png)
# ![pic4](images/pic4.png)
# ![pic5](images/pic5.png)
