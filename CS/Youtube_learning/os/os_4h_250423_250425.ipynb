# %% [markdown]
# ## Giving Credits to [Core Dumped](https://www.youtube.com/@CoreDumpped)!!

# %% [markdown]
# ### [Why is the heap so slow](https://youtu.be/ioJkA7Mw2-U?si=c9VTTyb-tZo2SwgA)
#
#
# the main difference between stack and heap: stack no fragmentation, heap has
# three strategies: First fit, Best fit, Worst fit
# Heap’s performance penalties: 1. heap needs to search the sub-regions for allocations 2. allocation may require a system call for more memory
# Runtime: 1. memory leak (consumes memory but fails to release it when it is no longer needed)2. null pointers dereferences 3. Dangling pointers
# Fragmentation
#
# pro: 1. Dynamic size 2. Large memory allocations 3. fast accessing time

# %% [markdown]
# ### [CONCURRENCY IS NOT WHAT YOU THINK](https://youtu.be/3X93PnKRNUo?si=zBlHJwhpif81RL5j)
#
# preemptive scheduling: OS sets a timer inside cpu before cpu is allocated to any process
#
# ### [A program is not a process](https://youtu.be/7ge7u5VUSbE?si=UXQRpdYwYY0Y3nd4)
#
# the TEXT and DATA are the same since they belong to the same program
#
# ![Pic1](images/pic1.png "Pic1")
# ![Pic2](images/INTERPRETED.png "Pic2")

# %% [markdown]
# ### [The Most Successful Idea in Computer Science](https://www.youtube.com/watch?v=LDhoD4IVElkj)
#
# The context switch: take a snapshot of previous process, then execute the other one
# PCB: Process Control Block: pid(id of the process), state (status of a process), (PC(program counter), general_purpose_register, instruction_register, flags, stack_pointer, index_register)[CPU state], memory_limit, IO_devices, and open_files, parent, children(PCB is not process itself, just a representation)
# PCBs is stored in the ready queue for CPU to execute

# %%
### [How a Single Bit Inside Your Processor Shields Your Operating System's Integrity](https://www.youtube.com/watch?v=H4SDPLiUnv4)

![Pic3](images/kernel_mode.png "Pic3")
![Pic4](images/user_mode.png "Pic4")
#### privilege_instructions: help one software have more control of another software
#### Mode bit==1(an interupt can cause it): Privilege Mode(Kernel Mode): can execute every instructions in the instrction set
#### Mode bit ==0: restricted mode(User Mode)
#### Kernel Mode: I/O devices, Memory(MMU: Memory Management Unit), how interrupts are handled

#### A timer is built in the cpu and can only be controlled by the privileged instructions
# Out:
# zsh:1: unknown file attribute: i
# zsh:1: unknown file attribute: i

# %% [markdown]
# ### [How the Clock Tells the CPU to "Move Forward"](https://www.youtube.com/watch?v=PVNAPWUxZ0g)
# rising edge, falling edge
#
# ### [IPC: To Share Memory Or To Send Messages](https://www.youtube.com/watch?v=Y2mDwW2pMv4)
#
# ![Pic5](images/PROCESS.png "Pic5")
# ![Pic6](images/Message.png "Pic6")
#
# ![Pic7](images/Passing_1.png "Pic7")
# ![Pic8](images/Passing_2.png "Pic8")
# ![Pic9](images/mailbox.png "Pic9")
# ![Pic10](images/Message_Passing.png "Pic10")
# ![Pic11](images/Shared_Memory.png "Pic11")
#
# 99% situation: message passing is quicker

# %% [markdown]
# ### [Why Are Threads Needed On Single Core Processors](https://www.youtube.com/watch?v=M9HHWFp84f0&t=159s)
#
# ![Pic12](images/thread_1.png "Pic12")
#
# ![Pic13](images/thread_2.png "Pic13")
#
# ![Pic14](images/thread_3.png "Pic14")
#
# ![Pic15](images/thread_4.png "Pic15")
#
# ![Pic16](images/thread_5.png "Pic16")

# %% [markdown]
# ### [Threads On Multicore Systems](https://www.youtube.com/watch?v=5sw9XJokAqw)
#
# ![Pic17](images/multithread1.png "Pic17")
# ![Pic18](images/multithread2.png "Pic18")
# data parallelism: to find the prime numbers
# ![Pic19](images/multithread3.png "Pic19")
# task parallelism
# ![Pic20](images/multithread4.png "Pic20")

# %% [markdown]
# ### [Why Applications Are Operating-System Specific](https://www.youtube.com/watch?v=eP_P4KOjwhs)
# A id of syscall will be stored in a register and then OS in kernel mode will refer to that id in the syscall table
#
# ![Pic21](images/app1.png "Pic21")
# ![Pic22](images/app2.png "Pic22")

# %% [markdown]
# ### [How Hardware Assist Software When Multitasking](https://www.youtube.com/watch?v=1HHeyUVz43k)
#
# ![Pic23](images/multitask1.png "Pic23")
# ![Pic24](images/multitask2.png "Pic24")
# ![Pic25](images/multitask3.png "Pic25")
